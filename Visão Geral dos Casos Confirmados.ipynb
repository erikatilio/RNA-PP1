# %% [markdown]
# # Visão Geral dos Casos Confirmados

# %% [markdown]
# ## Importando bibliotecas e a Base de Dados '05/08/2020'

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dataframe/Manaus.csv', sep=';', low_memory=False)

# %% [markdown]
# ## Realizando o filtro na coluna '_classificacao' onde seja Confirmado

# %%
df_cases_confirmed = df[df['_classificacao'].isin(['Confirmado'])]

# %% [markdown]
# #### 1. Quantos atributos descrevem cada exemplo? Quais são eles?

# %%
print("Total de ",df.shape[1]," atributos que descrevem cada exemplo, sendo eles:")
df_columns = df.columns.to_numpy()
for i in df_columns:
    print(i)
# Out:
# Total de  36  atributos que descrevem cada exemplo, sendo eles:
# _idade
# _faixa etária
# _sexo
# _bairro
# _classificacao
# _comorb_renal
# _comorb_diabetes
# _comorb_imuno
# _comorb_cardio
# _conclusao
# _dt_notificacao
# _taxa
# _dt_evolucao
# _raca
# _dt_sintomas
# _criterio
# _tipo_teste
# _sintoma_garganta
# _sintoma_dispneia
# _sintoma_febre
# _sintoma_tosse
# _sintoma_outros
# _etnia
# _profiss_saude
# _srag
# _se_notificacao
# _distrito
# _bairro_mapa
# _comorb_respiratoria
# _comorb_cromossomica
# _comorb_hepatica
# _comorb_neurologica
# _comorb_hemato
# _comorb_obessidade
# _origem
# _evolução

# %% [markdown]
# #### 2. Quantos casos confirmados há em Manaus, cumulativamente?

# %%
print("Total de {} casos confirmados em Manaus.".format(df_cases_confirmed.shape[0]))
# Out:
# Total de 36671 casos confirmados em Manaus.

# %% [markdown]
# #### 3. A qual período de tempo a base de dados se refere, isto é, qual o registro mais antigo e qual o mais recente? Leve em conta a data de notificação.

# %%
df_dates = df_cases_confirmed['_dt_notificacao'].drop_duplicates().dropna().to_numpy()
array_dates = np.sort(df_dates)
print("O registro mais antigo eh de '{}' e o mais recente de '{}'.".format(array_dates[0],array_dates[-1]))
# Out:
# O registro mais antigo eh de '01/04/2020' e o mais recente de '31/07/2020'.

# %% [markdown]
# ## Para fins da análise considerada no escopo deste projeto, vamos excluir todos os atributos relativos às comorbidades, sintomas, etnia, profissão, outras datas que não a de notificação, origem e outros que não estiverem envolvidos no contexto do trabalho solicitado. Estes atributos serão considerados irrelevantes para fins de simplificação. Exclua todas as linhas em que houver dados faltantes para os atributos remanescentes. Visando efetuar uma análise exploratória dos dados, respondam, pelo menos, às seguintes questões:

# %% [markdown]
# #### 1. Quantos exemplos e atributos há na base de dados após a  limpeza e organização ?

# %%
df_cases_confirmed = df_cases_confirmed.drop(['_comorb_renal', '_comorb_diabetes', '_comorb_imuno', '_comorb_cardio', '_comorb_respiratoria', '_comorb_cromossomica', '_comorb_hepatica', '_comorb_neurologica', '_comorb_hemato', '_comorb_obessidade', '_sintoma_garganta', '_sintoma_dispneia', '_sintoma_febre', '_sintoma_tosse', '_sintoma_outros', '_etnia', '_profiss_saude', '_dt_evolucao', '_dt_sintomas', '_raca', '_srag', '_origem', '_evolução', '_criterio'], axis=1)
df_cases_confirmed.dropna()
# Out:
#         _idade _faixa etária _sexo                _bairro _classificacao  \
# 678       25.0     20a - 29a     F           ADRIANOPOLIS     Confirmado
# 679       41.0     40a - 49a     F                BETANIA     Confirmado
# 66797     37.0     30a - 39a     M            CIDADE NOVA     Confirmado
# 66799     44.0     40a - 49a     M              SAO JORGE     Confirmado
# 66800     27.0     20a - 29a     F     COLONIA TERRA NOVA     Confirmado
# 66802     45.0     40a - 49a     M                 ALEIXO     Confirmado
# 66803     34.0     30a - 39a     M                COROADO     Confirmado
# 66805     32.0     30a - 39a     F             TERRA NOVA     Confirmado
# 66806     24.0     20a - 29a     F    MONTE DAS OLIVEIRAS     Confirmado
# 66807     33.0     30a - 39a     M          CIDADE NOVA 2     Confirmado
# 66808     36.0     30a - 39a     F            CIDADE NOVA     Confirmado
# 66817     66.0     60a - 69a     F            TARUMA  ACU     Confirmado
# 66855     31.0     30a - 39a     M      SAO JOSE OPERARIO     Confirmado
# 66858     47.0     40a - 49a     F             ALVORADA 2     Confirmado
# 66866     34.0     30a - 39a     M               REDENCAO     Confirmado
# 66868     52.0     50a - 59a     F           SAO RAIMUNDO     Confirmado
# 66869     50.0     50a - 59a     F              SAO JORGE     Confirmado
# 66871     47.0     40a - 49a     M                 TARUMA     Confirmado
# 66872     27.0     20a - 29a     F      PARQUE DAS NACOES     Confirmado
# 66882     26.0     20a - 29a     F         JORGE TEIXEIRA     Confirmado
# 66883     25.0     20a - 29a     F                COROADO     Confirmado
# 66886     52.0     50a - 59a     M              PARQUE 10     Confirmado
# 66887     38.0     30a - 39a     M                COROADO     Confirmado
# 66888     21.0     20a - 29a     M         TANCREDO NEVES     Confirmado
# 66889     53.0     50a - 59a     F                COROADO     Confirmado
# 66902     55.0     50a - 59a     F           SAO JOSE III     Confirmado
# 66913     47.0     40a - 49a     F  PARQUE DAS LARANJEIRA     Confirmado
# 66915     45.0     40a - 49a     F                 JAPIIM     Confirmado
# 66916     49.0     40a - 49a     F                 TARUMA     Confirmado
# 66917     53.0     50a - 59a     F            ALVORADA II     Confirmado
# ...        ...           ...   ...                    ...            ...
# 107134    73.0     70a - 79a     M         JORGE TEIXEIRA     Confirmado
# 107135    78.0     70a - 79a     M         NOVA ESPERANCA     Confirmado
# 107136     7.0       5a - 9a     F               COMPENSA     Confirmado
# 107141    52.0     50a - 59a     M         TANCREDO NEVES     Confirmado
# 107142    58.0     50a - 59a     M                 FLORES     Confirmado
# 107143    33.0     30a - 39a     M            PONTA NEGRA     Confirmado
# 107145    57.0     50a - 59a     F               ALVORADA     Confirmado
# 107148    30.0     30a - 39a     F            PONTA NEGRA     Confirmado
# 107151    47.0     40a - 49a     F             PETROPOLIS     Confirmado
# 107155    42.0     40a - 49a     F     GILBERTO MESTRINHO     Confirmado
# 107156    67.0     60a - 69a     M                COROADO     Confirmado
# 107158    44.0     40a - 49a     M               COMPENSA     Confirmado
# 107159    66.0     60a - 69a     F            CIDADE NOVA     Confirmado
# 107160    40.0     40a - 49a     F                 TARUMA     Confirmado
# 107161     2.0       1a - 4a     F         JORGE TEIXEIRA     Confirmado
# 107163    33.0     30a - 39a     M               REDENCAO     Confirmado
# 107164    65.0     60a - 69a     F             PETROPOLIS     Confirmado
# 107165    55.0     50a - 59a     F                 FLORES     Confirmado
# 107166    59.0     50a - 59a     F          LIRIO DO VALE     Confirmado
# 107167    46.0     40a - 49a     M          LIRIO DO VALE     Confirmado
# 107169    36.0     30a - 39a     F                 CENTRO     Confirmado
# 107170    49.0     40a - 49a     M               ALVORADA     Confirmado
# 107182    40.0     40a - 49a     F            CIDADE NOVA     Confirmado
# 107184    76.0     70a - 79a     F            NOVO ISRAEL     Confirmado
# 107193     0.0          < 1a     M            NOVO ALEIXO     Confirmado
# 107196    14.0     10a - 14a     F                 DA PAZ     Confirmado
# 107202     5.0       5a - 9a     F               REDENCAO     Confirmado
# 107204    70.0     70a - 79a     F            DOM PEDRO I     Confirmado
# 107212    68.0     60a - 69a     M         JORGE TEIXEIRA     Confirmado
# 107215    45.0     40a - 49a     F                 TARUMA     Confirmado
#
#         _conclusao _dt_notificacao        _taxa               _tipo_teste  \
# 678     Recuperado      20/03/2020   0,99960016                    RT-PCR
# 679     Recuperado      27/03/2020  0,801603206                    RT-PCR
# 66797   Recuperado      27/04/2020  0,068152389  TESTE RÁPIDO - ANTICORPO
# 66799   Recuperado      27/04/2020  0,381446445  TESTE RÁPIDO - ANTICORPO
# 66800   Recuperado      24/04/2020  0,183150183  TESTE RÁPIDO - ANTICORPO
# 66802   Recuperado      24/04/2020  0,444325958  TESTE RÁPIDO - ANTICORPO
# 66803   Recuperado      27/04/2020  0,160758781  TESTE RÁPIDO - ANTICORPO
# 66805   Recuperado      24/04/2020  0,183150183  TESTE RÁPIDO - ANTICORPO
# 66806   Recuperado      30/04/2020  0,205558296  TESTE RÁPIDO - ANTICORPO
# 66807   Recuperado      27/04/2020  0,068152389  TESTE RÁPIDO - ANTICORPO
# 66808   Recuperado      24/04/2020  0,068152389  TESTE RÁPIDO - ANTICORPO
# 66817   Recuperado      13/04/2020  0,684931507                    RT-PCR
# 66855   Recuperado      29/04/2020  0,124766064  TESTE RÁPIDO - ANTICORPO
# 66858   Recuperado      20/04/2020  0,127754711  TESTE RÁPIDO - ANTICORPO
# 66866   Recuperado      29/04/2020  0,234763828  TESTE RÁPIDO - ANTICORPO
# 66868   Recuperado      24/04/2020  0,536250536  TESTE RÁPIDO - ANTICORPO
# 66869   Recuperado      23/04/2020  0,381446445  TESTE RÁPIDO - ANTICORPO
# 66871   Recuperado      22/04/2020  0,243042897  TESTE RÁPIDO - ANTICORPO
# 66872   Recuperado      20/04/2020  0,198306463  TESTE RÁPIDO - ANTICORPO
# 66882   Recuperado      29/04/2020  0,073137374  TESTE RÁPIDO - ANTICORPO
# 66883   Recuperado      29/04/2020  0,160758781  TESTE RÁPIDO - ANTICORPO
# 66886   Recuperado      29/04/2020  0,228326141  TESTE RÁPIDO - ANTICORPO
# 66887   Recuperado      16/04/2020  0,160758781   TESTE RÁPIDO - ANTÍGENO
# 66888   Recuperado      29/04/2020  0,169058849  TESTE RÁPIDO - ANTICORPO
# 66889   Recuperado      09/06/2020  0,160758781  TESTE RÁPIDO - ANTICORPO
# 66902   Recuperado      29/04/2020  0,124766064                    RT-PCR
# 66913   Recuperado      28/04/2020  0,198306463  TESTE RÁPIDO - ANTICORPO
# 66915   Recuperado      29/04/2020  0,173837462                    RT-PCR
# 66916   Recuperado      20/04/2020  0,243042897  TESTE RÁPIDO - ANTICORPO
# 66917   Recuperado      20/04/2020  0,127754711  TESTE RÁPIDO - ANTICORPO
# ...            ...             ...          ...                       ...
# 107134  Recuperado      12/04/2020  0,073137374                    RT-PCR
# 107135  Recuperado      14/05/2020  0,466526709                    RT-PCR
# 107136  Recuperado      29/05/2020  0,108867236  TESTE RÁPIDO - ANTICORPO
# 107141  Recuperado      15/06/2020  0,169058849                    RT-PCR
# 107142  Recuperado      09/05/2020  0,198306463  TESTE RÁPIDO - ANTICORPO
# 107143  Recuperado      06/04/2020  1,648804617                    RT-PCR
# 107145  Recuperado      08/04/2020  0,127754711                    RT-PCR
# 107148  Recuperado      15/04/2020  1,648804617  TESTE RÁPIDO - ANTICORPO
# 107151  Recuperado      08/06/2020  0,232948192  TESTE RÁPIDO - ANTICORPO
# 107155  Recuperado      06/05/2020  0,149162453                    RT-PCR
# 107156  Recuperado      05/05/2020  0,160758781                    RT-PCR
# 107158  Recuperado      07/04/2020  0,108867236  TESTE RÁPIDO - ANTICORPO
# 107159  Recuperado      17/04/2020  0,068152389  TESTE RÁPIDO - ANTICORPO
# 107160  Recuperado      20/06/2020  0,243042897                    RT-PCR
# 107161  Recuperado      24/06/2020  0,073137374  TESTE RÁPIDO - ANTICORPO
# 107163  Recuperado      31/03/2020  0,234763828                    RT-PCR
# 107164  Recuperado      18/05/2020  0,232948192  TESTE RÁPIDO - ANTICORPO
# 107165  Recuperado      01/05/2020  0,198306463   TESTE RÁPIDO - ANTÍGENO
# 107166       Óbito      03/06/2020  0,383376783                    RT-PCR
# 107167  Recuperado      18/06/2020  0,383376783                    RT-PCR
# 107169  Recuperado      27/03/2020  0,284843479   TESTE RÁPIDO - ANTÍGENO
# 107170  Recuperado      02/05/2020  0,127754711  TESTE RÁPIDO - ANTICORPO
# 107182  Recuperado      23/05/2020  0,068152389  TESTE RÁPIDO - ANTICORPO
# 107184  Recuperado      11/05/2020  0,490725292   TESTE RÁPIDO - ANTÍGENO
# 107193  Recuperado      28/06/2020  0,085452557  TESTE RÁPIDO - ANTICORPO
# 107196  Recuperado      25/06/2020  0,543389665   TESTE RÁPIDO - ANTÍGENO
# 107202  Recuperado      18/06/2020  0,234763828   TESTE RÁPIDO - ANTÍGENO
# 107204  Recuperado      02/06/2020  0,483629153   TESTE RÁPIDO - ANTÍGENO
# 107212  Recuperado      01/06/2020  0,073137374                    RT-PCR
# 107215  Recuperado      05/06/2020  0,243042897  TESTE RÁPIDO - ANTICORPO
#
#         _se_notificacao _distrito           _bairro_mapa
# 678                12.0       SUL           ADRIANÓPOLIS
# 679                13.0       SUL                BETÂNIA
# 66797              18.0     NORTE            CIDADE NOVA
# 66799              18.0     OESTE              SÃO JORGE
# 66800              17.0     NORTE     COLÔNIA TERRA NOVA
# 66802              17.0       SUL                 ALEIXO
# 66803              18.0     LESTE                COROADO
# 66805              17.0     NORTE     COLÔNIA TERRA NOVA
# 66806              18.0     NORTE    MONTE DAS OLIVEIRAS
# 66807              18.0     NORTE            CIDADE NOVA
# 66808              17.0     NORTE            CIDADE NOVA
# 66817              16.0     OESTE             TARUMÃ-AÇÚ
# 66855              18.0     LESTE      SÃO JOSÉ OPERÁRIO
# 66858              17.0     OESTE               ALVORADA
# 66866              18.0     OESTE               REDENÇÃO
# 66868              17.0     OESTE           SÃO RAIMUNDO
# 66869              17.0     OESTE              SÃO JORGE
# 66871              17.0     OESTE                 TARUMÃ
# 66872              17.0       SUL                 FLORES
# 66882              18.0     LESTE         JORGE TEIXEIRA
# 66883              18.0     LESTE                COROADO
# 66886              18.0       SUL  PARQUE 10 DE NOVEMBRO
# 66887              16.0     LESTE                COROADO
# 66888              18.0     LESTE         TANCREDO NEVES
# 66889              24.0     LESTE                COROADO
# 66902              18.0     LESTE      SÃO JOSÉ OPERÁRIO
# 66913              18.0       SUL                 FLORES
# 66915              18.0       SUL                 JAPIIM
# 66916              17.0     OESTE                 TARUMÃ
# 66917              17.0     OESTE               ALVORADA
# ...                 ...       ...                    ...
# 107134             16.0     LESTE         JORGE TEIXEIRA
# 107135             20.0     OESTE         NOVA ESPERANÇA
# 107136             22.0     OESTE               COMPENSA
# 107141             25.0     LESTE         TANCREDO NEVES
# 107142             19.0       SUL                 FLORES
# 107143             15.0     OESTE            PONTA NEGRA
# 107145             15.0     OESTE               ALVORADA
# 107148             16.0     OESTE            PONTA NEGRA
# 107151             24.0       SUL             PETRÓPOLIS
# 107155             19.0     LESTE     GILBERTO MESTRINHO
# 107156             19.0     LESTE                COROADO
# 107158             15.0     OESTE               COMPENSA
# 107159             16.0     NORTE            CIDADE NOVA
# 107160             25.0     OESTE                 TARUMÃ
# 107161             26.0     LESTE         JORGE TEIXEIRA
# 107163             14.0     OESTE               REDENÇÃO
# 107164             21.0       SUL             PETRÓPOLIS
# 107165             18.0       SUL                 FLORES
# 107166             23.0     OESTE          LÍRIO DO VALE
# 107167             25.0     OESTE          LÍRIO DO VALE
# 107169             13.0       SUL                 CENTRO
# 107170             18.0     OESTE               ALVORADA
# 107182             21.0     NORTE            CIDADE NOVA
# 107184             20.0     NORTE            NOVO ISRAEL
# 107193             27.0     NORTE            NOVO ALEIXO
# 107196             26.0     OESTE                 DA PAZ
# 107202             25.0     OESTE               REDENÇÃO
# 107204             23.0     OESTE              DOM PEDRO
# 107212             23.0     LESTE         JORGE TEIXEIRA
# 107215             23.0     OESTE                 TARUMÃ
#
# [6145 rows x 12 columns]

# %% [markdown]
# #### 2. Qual a porcentagem de indivíduos recuperados em relação ao todo?

# %%
amount_recovered = int(df[df['_conclusao'].isin(['Recuperado'])].shape[0])
amount_total = int(df.shape[0])

print("Total de casos: {}\nTotal recuperado: {} = %{:.0f}".format(amount_total, amount_recovered, ((amount_recovered*100)/amount_total)))
# Out:
# Total de casos: 107221
# Total recuperado: 60671 = %57
